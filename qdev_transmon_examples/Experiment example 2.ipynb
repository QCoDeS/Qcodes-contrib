# %% [markdown]
# ## Initialise

# %%
import qcodes as qc
import numpy as np
import sys
# %matplotlib nbagg

helper_fns_folder = '/Users/Natalie/Documents/PhD/Qdev/QcodesRelated/HelperScripts'# r'C:\Users\qcodes-natalie\Qcodes-contrib' # TODO: enter path to transmon helper folder
if helper_fns_folder not in sys.path:
    sys.path.insert(0, helper_fns_folder)

from qdev_transmon_helpers import *

# %%
set_sample_name('testing_bugs_2')

# %%
set_file_locations()
# Out:
# Set up python log location: /Users/Natalie/Documents/PhD/Qdev/QcodesRelated/Qcodes_test_data/testing_bugs_2/log_files/python_logs/
# -------------------------
# Activating auto-logging. Current session state plus future input saved.
# Filename       : /Users/Natalie/Documents/PhD/Qdev/QcodesRelated/Qcodes_test_data/testing_bugs_2/log_files/jupyter_logs/2017-07-04_20-23-42_ipythonlogfile.txt
# Mode           : append
# Output logging : False
# Raw input log  : False
# Timestamping   : True
# State          : active
# Set up jupyter log location: /Users/Natalie/Documents/PhD/Qdev/QcodesRelated/Qcodes_test_data/testing_bugs_2/log_files/jupyter_logs/
# -------------------------
# Set data location: /Users/Natalie/Documents/PhD/Qdev/QcodesRelated/Qcodes_test_data/testing_bugs_2/data/
# -------------------------
# Set data file format: {counter}
# -------------------------
# Set up analysis location: /Users/Natalie/Documents/PhD/Qdev/QcodesRelated/Qcodes_test_data/testing_bugs_2/analysis/
# -------------------------
# Set up pulse location: /Users/Natalie/Documents/PhD/Qdev/QcodesRelated/Qcodes_test_data/testing_bugs_2/pulse_lib/
# -------------------------
# Set up temp dict location: /Users/Natalie/Documents/PhD/Qdev/QcodesRelated/Qcodes_test_data/testing_bugs_2/temp_dicts/
# -------------------------

# %%
set_qubit_count(3)

# %%
set_current_qubit(1)

# %%
station = qc.Station()

# %%
get_qubit_count()
# Out:
# 3

# %%
get_calibration_dict()
# Out:
# defaultdict(<function qdev_transmon_helpers.temp_dict_funtions.dd_f>,
#             {'current_qubit': 1,
#              'cycle_time': array([  2.00000000e-05,   1.50000000e-05,   2.00000000e-05]),
#              'drag_coef': array([ 0. ,  0.2,  0. ]),
#              'marker_readout_delay': array([0, 0, 0]),
#              'marker_time': array([  5.00000000e-07,   5.00000000e-07,   5.00000000e-07]),
#              'pi_half_pulse_amp': array([ 0.5,  0.5,  0.5]),
#              'pi_half_pulse_dur': array([None, 1e-07, None], dtype=object),
#              'pi_half_pulse_sigma': array([None, 1e-07, None], dtype=object),
#              'pi_pulse_amp': array([1, 1, 1]),
#              'pi_pulse_dur': array([None, 1e-07, None], dtype=object),
#              'pi_pulse_sigma': array([None, 1e-08, None], dtype=object),
#              'pulse_end': array([  1.00000000e-05,   1.00000000e-05,   1.00000000e-05]),
#              'pulse_mod_time': array([  1.50000000e-06,   1.50000000e-06,   1.50000000e-06]),
#              'pulse_readout_delay': array([  3.00000000e-08,   3.00000000e-08,   3.00000000e-08]),
#              'qubit_freq': array([  0.00000000e+00,   1.00000000e+09,   0.00000000e+00]),
#              'qubit_spec_time': array([  1.00000000e-06,   1.00000000e-06,   1.00000000e-06]),
#              'readout_amp': array([1, 1, 1]),
#              'readout_time': array([  4.00000000e-06,   4.00000000e-06,   4.00000000e-06]),
#              'sample_rate': array([  1.00000000e+09,   1.00000000e+09,   1.00000000e+09]),
#              'sigma_cutoff': array([4, 4, 4]),
#              'z_half_pulse_amp': array([None, None, None], dtype=object),
#              'z_half_pulse_dur': array([None, None, None], dtype=object),
#              'z_pulse_amp': array([None, None, None], dtype=object),
#              'z_pulse_dur': array([None, None, None], dtype=object)})

# %%
seq = pb.make_benchmarking_sequence(1, 5, gaussian=False)

# %%
seq.print_segment_lists(elemnum=0, channels=[1, 2, 4])
# Out:
# ch  1 :  wait|-pi/2  |pi/2   |wait|wait_measurement  |wait
# ch  2 :  wait|XY_wait|XY_wait|wait|wait_measurement  |wait
# ch  4 :  wait|XY_wait|XY_wait|wait|cavity_measurement|wait

# %%
pl = seq.plot(elemnum=0, channels=[1, 2, 4])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
set_calibration_val('cycle_time', 15e-6)
set_calibration_val('pulse_end', 10e-6)

# %%
c_ssb = pb.make_spectroscopy_SSB_sequence(0, 200e6, 1e6, channels=[3, 1, 2], pulse_mod=True)

# %%
pl = c_ssb.plot(elemnum=1, channels = [1,2,3])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
rabi = pb.make_rabi_sequence(0, 100e-9, 5e-9, pulse_mod=True, gaussian=True, SSBfreq=10e6)

# %%
pl = rabi.plot(elemnum=20, channels=[1, 2, 4])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
t1 = pb.make_t1_sequence(0, 1e-6, 10e-9, pi_dur=0.1e-6, pi_amp=0.4, pulse_mod=True, SSBfreq=10e6)

# %%
pl = t1.plot(elemnum=2, channels=[1, 2, 4])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
t1.print_segment_lists(channels=[1, 4])
# Out:
# ch 1: [compensating_wait, gaussian_SSB_pi_I_pulse, pulse_readout_delay, wait]
# ch 4: [wait_before_measurement, cavity_measurement, wait_after_measurement]

# %%
ramsey = pb.make_ramsey_sequence(0, 1e-6, 100e-9, SSBfreq=10e6, pulse_mod=True)

# %%
pl = ramsey.plot(elemnum=10, channels=[1, 4])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# vna = helpers.import_vna()
# dec_slots, dec_chans = helpers.import_decadac()
dummy_time = import_manual_param()
# Out:
# imported manual parameter: 'dummy_time'
# -------------------------

# %%
dummy_time(3)
data, plots = measure(dummy_time)
# Out:
# DataSet:
#    location = '/Users/Natalie/Documents/PhD/Qdev/QcodesRelated/Qcodes_test_data/testing_bugs_2/data/003'
#    <Type>   | <array_id> | <array.name> | <array.shape>
#    Setpoint | single_set | single       | (1,)
#    Measured | dummy_time | dummy_time   | (1,)
# acquired at 2017-07-03 19:16:01
# warning: plots not saved. To save one choose and run plots[i].save()

# %% [markdown]
# ## Find all Resonators

# %%
# actual measurement

resonator_sweep_setup(v1)
data, plot = measure(v1.trace)
# Out:
# DataSet:
#    mode     = DataMode.LOCAL
#    location = 'A:/TransmonExperiments/GoogleDrive/T2acquisition/Data/KDP78C0_qcodes3/data/027'
#    <Type>   | <array_id>    | <array.name> | <array.shape>
#    Measured | frequency     | frequency    | (2001,)
#    Measured | VNA_magnitude | magnitude    | (2001,)
#    Measured | VNA_phase     | phase        | (2001,)
# acquired at 2017-01-10 18:09:50

# %%
# load data
data, plot = load(12)

# %% [markdown]
# ### Find Resonator Positions

# %%
#fs = 400e6 * 2001 # sampling frequency used for smoothing  (ie span * npts)

fs = (v1.stop.get_latest() - v1.start.get_latest()) * v1.npts.get_latest()

indices, resonances_array, res_attempt_plot = find_peaks(data, fs)
save_plot(res_attempt_plot)
# Out:
# <img src="data:image/png;base64,...">
# 10 resonances found at [  7.12320000e+09   7.16960000e+09   7.20980000e+09   7.24640000e+09
#    7.28400000e+09   7.32560000e+09   7.34580000e+09   7.40060000e+09
#    7.41740000e+09   7.42220000e+09]

# %% [markdown]
# ## Power Sweeps (qubits alive?)

# %%
# actual measurement

power_sweep_setup(v1)
pow_sweeps = []

for f in resonances_array:
    dat, pl = do_power_sweep(v1, f)
    pow_sweeps.append(dat)
# Out:
# DataSet:
#    mode     = DataMode.LOCAL
#    location = 'A:/TransmonExperiments/GoogleDrive/T2acquisition/Data/KDP78C0_qcodes3/data/028'
#    <Type>   | <array_id>    | <array.name> | <array.shape>
#    Setpoint | VNA_power_set | power        | (41,)
#    Measured | frequency     | frequency    | (41, 201)
#    Measured | VNA_magnitude | magnitude    | (41, 201)
#    Measured | VNA_phase     | phase        | (41, 201)
# started at 2017-01-10 18:11:46
# DataSet:
#    mode     = DataMode.LOCAL
#    location = 'A:/TransmonExperiments/GoogleDrive/T2acquisition/Data/KDP78C0_qcodes3/data/029'
#    <Type>   | <array_id>    | <array.name> | <array.shape>
#    Setpoint | VNA_power_set | power        | (41,)
#    Measured | frequency     | frequency    | (41, 201)
#    Measured | VNA_magnitude | magnitude    | (41, 201)
#    Measured | VNA_phase     | phase        | (41, 201)
# started at 2017-01-10 18:12:31
# DataSet:
#    mode     = DataMode.LOCAL
#    location = 'A:/TransmonExperiments/GoogleDrive/T2acquisition/Data/KDP78C0_qcodes3/data/030'
#    <Type>   | <array_id>    | <array.name> | <array.shape>
#    Setpoint | VNA_power_set | power        | (41,)
#    Measured | frequency     | frequency    | (41, 201)
#    Measured | VNA_magnitude | magnitude    | (41, 201)
#    Measured | VNA_phase     | phase        | (41, 201)
# started at 2017-01-10 18:13:16
# DataSet:
#    mode     = DataMode.LOCAL
#    location = 'A:/TransmonExperiments/GoogleDrive/T2acquisition/Data/KDP78C0_qcodes3/data/031'
#    <Type>   | <array_id>    | <array.name> | <array.shape>
#    Setpoint | VNA_power_set | power        | (41,)
#    Measured | frequency     | frequency    | (41, 201)
#    Measured | VNA_magnitude | magnitude    | (41, 201)
#    Measured | VNA_phase     | phase        | (41, 201)
# started at 2017-01-10 18:14:02
# DataSet:
#    mode     = DataMode.LOCAL
#    location = 'A:/TransmonExperiments/GoogleDrive/T2acquisition/Data/KDP78C0_qcodes3/data/032'
#    <Type>   | <array_id>    | <array.name> | <array.shape>
#    Setpoint | VNA_power_set | power        | (41,)
#    Measured | frequency     | frequency    | (41, 201)
#    Measured | VNA_magnitude | magnitude    | (41, 201)
#    Measured | VNA_phase     | phase        | (41, 201)
# started at 2017-01-10 18:14:47
# DataSet:
#    mode     = DataMode.LOCAL
#    location = 'A:/TransmonExperiments/GoogleDrive/T2acquisition/Data/KDP78C0_qcodes3/data/033'
#    <Type>   | <array_id>    | <array.name> | <array.shape>
#    Setpoint | VNA_power_set | power        | (41,)
#    Measured | frequency     | frequency    | (41, 201)
#    Measured | VNA_magnitude | magnitude    | (41, 201)
#    Measured | VNA_phase     | phase        | (41, 201)
# started at 2017-01-10 18:15:33
